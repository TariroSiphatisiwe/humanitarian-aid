# %% [markdown]
# # 1.0 Predictive Analysis for Humanitarian Aid
#
# ### 1.1 Problem definition
#
# Predictive analytics to help organisations such as the United Nations(UN) to allocate resources more promptly and effectively to Humanitarian Crisis areas as well as provide an objective base for vulnerability assessment and priority setting.
#
# This is achieved by analysing historical data on natural disasters, conflict zones, and other relevant factors.
#
# This notebook also provides Key insights to the Natural Disasters database which contains over 22,000 mass disasters as of 1900 to 2021
#
# ### 1.2 Data and acknowledgements
# Sourced from https://www.kaggle.com/datasets/jnegrini/emdat19002021
#
#
# ### 1.3 Acknowledgements
# TThe credit for creating and maintaining the Database is for the Centre for Research on the Epidemiology of Disasters - CRED and the School of Public Health from the Université catholique de Louvain.
#
# “EM-DAT, CRED / UCLouvain, Brussels, Belgium – www.emdat.be (D. Guha-Sapir)”
#
#
# ### 1.4 Content
# For an event to be registered into the EM-DAT database it must fulfill one of three entry criteria:
#
# Deaths: 10 or more people deaths
#
# Affected: 100 or more people affected/injured/homeless.
#
# Declaration/international appeal: Declaration by the country of a state of emergency and/or an appeal for international assistance
#
#
# ### 1.5 Key Insights
# .
#
# ..
#
# ...
#
# ....

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
from matplotlib.colors import ListedColormap
import random
from matplotlib.ticker import ScalarFormatter
#import cartopy.crs as ccrs

# %% [markdown]
# # Exploritory Data Analysis with Visualisations.

# %% [markdown]
# Importing 1900_2021_DISASTERS.xlsx - emdat data.csv found in the directory of the humanitarian aid folder.

# %%
#reading csv file

emdata_org = pd.read_csv('1900_2021_DISASTERS.xlsx - emdat data.csv')
emdata_org.head()
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup      Disaster Type  \
# 0  1900  9002   NaN        Natural    Climatological            Drought
# 1  1900  9001   NaN        Natural    Climatological            Drought
# 2  1902    12   NaN        Natural       Geophysical         Earthquake
# 3  1902     3   NaN        Natural       Geophysical  Volcanic activity
# 4  1902    10   NaN        Natural       Geophysical  Volcanic activity
#
#   Disaster Subtype Disaster Subsubtype   Event Name     Country  ...  \
# 0          Drought                 NaN          NaN  Cabo Verde  ...
# 1          Drought                 NaN          NaN       India  ...
# 2  Ground movement                 NaN          NaN   Guatemala  ...
# 3         Ash fall                 NaN  Santa Maria   Guatemala  ...
# 4         Ash fall                 NaN  Santa Maria   Guatemala  ...
#
#   No Affected No Homeless Total Affected Insured Damages ('000 US$)  \
# 0         NaN         NaN            NaN                        NaN
# 1         NaN         NaN            NaN                        NaN
# 2         NaN         NaN            NaN                        NaN
# 3         NaN         NaN            NaN                        NaN
# 4         NaN         NaN            NaN                        NaN
#
#   Total Damages ('000 US$)       CPI Adm Level Admin1 Code Admin2 Code  \
# 0                      NaN  3.221647       NaN         NaN         NaN
# 1                      NaN  3.221647       NaN         NaN         NaN
# 2                  25000.0  3.350513       NaN         NaN         NaN
# 3                      NaN  3.350513       NaN         NaN         NaN
# 4                      NaN  3.350513       NaN         NaN         NaN
#
#   Geo Locations
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Infomation on dataset
#
# The summaries below show information regarding the dataset
#
# 1. Data columns - 45
#
# 2. Entries - 16125
#
# 3. Data types - float64(14), int64(4), object(27)

# %%
emdata_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16126 entries, 0 to 16125
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        16126 non-null  int64
#  1   Seq                         16126 non-null  int64
#  2   Glide                       1581 non-null   object
#  3   Disaster Group              16126 non-null  object
#  4   Disaster Subgroup           16126 non-null  object
#  5   Disaster Type               16126 non-null  object
#  6   Disaster Subtype            13016 non-null  object
#  7   Disaster Subsubtype         1077 non-null   object
#  8   Event Name                  3861 non-null   object
#  9   Country                     16126 non-null  object
#  10  ISO                         16126 non-null  object
#  11  Region                      16126 non-null  object
#  12  Continent                   16126 non-null  object
#  13  Location                    14334 non-null  object
#  14  Origin                      3794 non-null   object
#  15  Associated Dis              3348 non-null   object
#  16  Associated Dis2             707 non-null    object
#  17  OFDA Response               1694 non-null   object
#  18  Appeal                      2569 non-null   object
#  19  Declaration                 3256 non-null   object
#  20  Aid Contribution            677 non-null    float64
#  21  Dis Mag Value               4946 non-null   float64
#  22  Dis Mag Scale               14936 non-null  object
#  23  Latitude                    2729 non-null   object
#  24  Longitude                   2732 non-null   object
#  25  Local Time                  1103 non-null   object
#  26  River Basin                 1287 non-null   object
#  27  Start Year                  16126 non-null  int64
#  28  Start Month                 15739 non-null  float64
#  29  Start Day                   12498 non-null  float64
#  30  End Year                    16126 non-null  int64
#  31  End Month                   15418 non-null  float64
#  32  End Day                     12570 non-null  float64
#  33  Total Deaths                11413 non-null  float64
#  34  No Injured                  3895 non-null   float64
#  35  No Affected                 9220 non-null   float64
#  36  No Homeless                 2430 non-null   float64
#  37  Total Affected              11617 non-null  float64
#  38  Insured Damages ('000 US$)  1096 non-null   float64
#  39  Total Damages ('000 US$)    5245 non-null   float64
#  40  CPI                         15811 non-null  float64
#  41  Adm Level                   7859 non-null   object
#  42  Admin1 Code                 4581 non-null   object
#  43  Admin2 Code                 3969 non-null   object
#  44  Geo Locations               7859 non-null   object
# dtypes: float64(14), int64(4), object(27)
# memory usage: 5.5+ MB

# %%
emdata_org.head(10).T
# Out:
#                                          0               1  \
# Year                                  1900            1900
# Seq                                   9002            9001
# Glide                                  NaN             NaN
# Disaster Group                     Natural         Natural
# Disaster Subgroup           Climatological  Climatological
# Disaster Type                      Drought         Drought
# Disaster Subtype                   Drought         Drought
# Disaster Subsubtype                    NaN             NaN
# Event Name                             NaN             NaN
# Country                         Cabo Verde           India
# ISO                                    CPV             IND
# Region                      Western Africa   Southern Asia
# Continent                           Africa            Asia
# Location                       Countrywide          Bengal
# Origin                                 NaN             NaN
# Associated Dis                      Famine             NaN
# Associated Dis2                        NaN             NaN
# OFDA Response                          NaN             NaN
# Appeal                                  No              No
# Declaration                             No              No
# Aid Contribution                       NaN             NaN
# Dis Mag Value                          NaN             NaN
# Dis Mag Scale                          Km2             Km2
# Latitude                               NaN             NaN
# Longitude                              NaN             NaN
# Local Time                             NaN             NaN
# River Basin                            NaN             NaN
# Start Year                            1900            1900
# Start Month                            NaN             NaN
# Start Day                              NaN             NaN
# End Year                              1900            1900
# End Month                              NaN             NaN
# End Day                                NaN             NaN
# Total Deaths                       11000.0       1250000.0
# No Injured                             NaN             NaN
# No Affected                            NaN             NaN
# No Homeless                            NaN             NaN
# Total Affected                         NaN             NaN
# Insured Damages ('000 US$)             NaN             NaN
# Total Damages ('000 US$)               NaN             NaN
# CPI                               3.221647        3.221647
# Adm Level                              NaN             NaN
# Admin1 Code                            NaN             NaN
# Admin2 Code                            NaN             NaN
# Geo Locations                          NaN             NaN
#
#                                                     2                  3  \
# Year                                             1902               1902
# Seq                                                12                  3
# Glide                                             NaN                NaN
# Disaster Group                                Natural            Natural
# Disaster Subgroup                         Geophysical        Geophysical
# Disaster Type                              Earthquake  Volcanic activity
# Disaster Subtype                      Ground movement           Ash fall
# Disaster Subsubtype                               NaN                NaN
# Event Name                                        NaN        Santa Maria
# Country                                     Guatemala          Guatemala
# ISO                                               GTM                GTM
# Region                                Central America    Central America
# Continent                                    Americas           Americas
# Location                    Quezaltenango, San Marcos                NaN
# Origin                                            NaN                NaN
# Associated Dis                     Tsunami/Tidal wave                NaN
# Associated Dis2                                   NaN                NaN
# OFDA Response                                     NaN                NaN
# Appeal                                            NaN                NaN
# Declaration                                       NaN                NaN
# Aid Contribution                                  NaN                NaN
# Dis Mag Value                                     8.0                NaN
# Dis Mag Scale                                 Richter                NaN
# Latitude                                           14                NaN
# Longitude                                         -91                NaN
# Local Time                                      20:20                NaN
# River Basin                                       NaN                NaN
# Start Year                                       1902               1902
# Start Month                                       4.0                4.0
# Start Day                                        18.0                8.0
# End Year                                         1902               1902
# End Month                                         4.0                4.0
# End Day                                          18.0                8.0
# Total Deaths                                   2000.0             1000.0
# No Injured                                        NaN                NaN
# No Affected                                       NaN                NaN
# No Homeless                                       NaN                NaN
# Total Affected                                    NaN                NaN
# Insured Damages ('000 US$)                        NaN                NaN
# Total Damages ('000 US$)                      25000.0                NaN
# CPI                                          3.350513           3.350513
# Adm Level                                         NaN                NaN
# Admin1 Code                                       NaN                NaN
# Admin2 Code                                       NaN                NaN
# Geo Locations                                     NaN                NaN
#
#                                             4                    5  \
# Year                                     1902                 1903
# Seq                                        10                    6
# Glide                                     NaN                  NaN
# Disaster Group                        Natural              Natural
# Disaster Subgroup                 Geophysical          Geophysical
# Disaster Type               Volcanic activity  Mass movement (dry)
# Disaster Subtype                     Ash fall             Rockfall
# Disaster Subsubtype                       NaN                  NaN
# Event Name                        Santa Maria                  NaN
# Country                             Guatemala               Canada
# ISO                                       GTM                  CAN
# Region                        Central America     Northern America
# Continent                            Americas             Americas
# Location                                  NaN       Frank, Alberta
# Origin                                    NaN                  NaN
# Associated Dis                            NaN                  NaN
# Associated Dis2                           NaN                  NaN
# OFDA Response                             NaN                  NaN
# Appeal                                    NaN                  NaN
# Declaration                               NaN                  NaN
# Aid Contribution                          NaN                  NaN
# Dis Mag Value                             NaN                  NaN
# Dis Mag Scale                             NaN                  NaN
# Latitude                                  NaN                  NaN
# Longitude                                 NaN                  NaN
# Local Time                                NaN                  NaN
# River Basin                               NaN                  NaN
# Start Year                               1902                 1903
# Start Month                              10.0                  4.0
# Start Day                                24.0                 29.0
# End Year                                 1902                 1903
# End Month                                10.0                  4.0
# End Day                                  24.0                 29.0
# Total Deaths                           6000.0                 76.0
# No Injured                                NaN                 23.0
# No Affected                               NaN                  NaN
# No Homeless                               NaN                  NaN
# Total Affected                            NaN                 23.0
# Insured Damages ('000 US$)                NaN                  NaN
# Total Damages ('000 US$)                  NaN                  NaN
# CPI                                  3.350513             3.479379
# Adm Level                                 NaN                  NaN
# Admin1 Code                               NaN                  NaN
# Admin2 Code                               NaN                  NaN
# Geo Locations                             NaN                  NaN
#
#                                             6                 7  \
# Year                                     1903              1904
# Seq                                        12                 3
# Glide                                     NaN               NaN
# Disaster Group                        Natural           Natural
# Disaster Subgroup                 Geophysical    Meteorological
# Disaster Type               Volcanic activity             Storm
# Disaster Subtype                     Ash fall  Tropical cyclone
# Disaster Subsubtype                       NaN               NaN
# Event Name                     Mount Karthala               NaN
# Country                         Comoros (the)        Bangladesh
# ISO                                       COM               BGD
# Region                         Eastern Africa     Southern Asia
# Continent                              Africa              Asia
# Location                                  NaN        Chittagong
# Origin                                    NaN               NaN
# Associated Dis                            NaN               NaN
# Associated Dis2                           NaN               NaN
# OFDA Response                             NaN               NaN
# Appeal                                     No               NaN
# Declaration                                No               NaN
# Aid Contribution                          NaN               NaN
# Dis Mag Value                             NaN               NaN
# Dis Mag Scale                             NaN               Kph
# Latitude                                  NaN               NaN
# Longitude                                 NaN               NaN
# Local Time                                NaN               NaN
# River Basin                               NaN               NaN
# Start Year                               1903              1904
# Start Month                               NaN              11.0
# Start Day                                 NaN               NaN
# End Year                                 1903              1904
# End Month                                 NaN              11.0
# End Day                                   NaN               NaN
# Total Deaths                             17.0               NaN
# No Injured                                NaN               NaN
# No Affected                               NaN               NaN
# No Homeless                               NaN               NaN
# Total Affected                            NaN               NaN
# Insured Damages ('000 US$)                NaN               NaN
# Total Damages ('000 US$)                  NaN               NaN
# CPI                                  3.479379          3.479379
# Adm Level                                 NaN               NaN
# Admin1 Code                               NaN               NaN
# Admin2 Code                               NaN               NaN
# Geo Locations                             NaN               NaN
#
#                                                             8                9
# Year                                                     1905             1905
# Seq                                                         5                3
# Glide                                                     NaN              NaN
# Disaster Group                                        Natural          Natural
# Disaster Subgroup                                 Geophysical      Geophysical
# Disaster Type                             Mass movement (dry)       Earthquake
# Disaster Subtype                                     Rockfall  Ground movement
# Disaster Subsubtype                                       NaN              NaN
# Event Name                                                NaN              NaN
# Country                                                Canada            India
# ISO                                                       CAN              IND
# Region                                       Northern America    Southern Asia
# Continent                                            Americas             Asia
# Location                    Spence's Bridge, British Columbia           Kangra
# Origin                                                    NaN              NaN
# Associated Dis                                            NaN              NaN
# Associated Dis2                                           NaN              NaN
# OFDA Response                                             NaN              NaN
# Appeal                                                    NaN              NaN
# Declaration                                               NaN              NaN
# Aid Contribution                                          NaN              NaN
# Dis Mag Value                                             NaN              8.0
# Dis Mag Scale                                             NaN          Richter
# Latitude                                                  NaN            32.04
# Longitude                                                 NaN            76.16
# Local Time                                                NaN            06:20
# River Basin                                               NaN              NaN
# Start Year                                               1905             1905
# Start Month                                               8.0              4.0
# Start Day                                                13.0              4.0
# End Year                                                 1905             1905
# End Month                                                 8.0              4.0
# End Day                                                  13.0              4.0
# Total Deaths                                             18.0          20000.0
# No Injured                                               18.0              NaN
# No Affected                                               NaN              NaN
# No Homeless                                               NaN              NaN
# Total Affected                                           18.0              NaN
# Insured Damages ('000 US$)                                NaN              NaN
# Total Damages ('000 US$)                                  NaN          25000.0
# CPI                                                  3.479379         3.479379
# Adm Level                                                 NaN              NaN
# Admin1 Code                                               NaN              NaN
# Admin2 Code                                               NaN              NaN
# Geo Locations                                             NaN              NaN

# %% [markdown]
# ## Death impact for each disaster group over time.
#
#
# ##### Climatological
# 1900 - 1980s , we see Climatological events having death impacts af a minimum of less than 5000 deaths
# Over time this subgroup has less or close to zero(O) Deaths recorderd.
#
#
# ##### Biological
# 1900 - 1920s, this subgroup has had death impacts in the early 1900s.
# Over time from 1900 -1920s the death impact was reducing.
# From 1900 -2021,  the deaths reduced to zero.
#
#
# ##### Extra-terrestrial
# Non recorded
#
# ##### Geophysical
# Has the most number of recorded deaths.
# From 1900 -2021 the subgroup has continued having death impacts.
#
# ##### Hydrological
# Impact of deaths was between 1920s and 1960s
# Over time there has been less impact.
#
# ##### Meteorological
# From 1900 -2021 the subgroup has continued having death impacts.

# %%
pd.crosstab(emdata_org.Year,emdata_org['Disaster Subgroup'])
# Out:
# Disaster Subgroup  Biological  Climatological  Extra-terrestrial  Geophysical  \
# Year
# 1900                        1               2                  0            2
# 1901                        1               0                  0            1
# 1902                        0               0                  0            9
# 1903                        0               1                  0            7
# 1904                        0               0                  0            3
# ...                       ...             ...                ...          ...
# 2017                       27              27                  0           25
# 2018                       16              27                  0           30
# 2019                       44              29                  0           36
# 2020                        8              17                  0           20
# 2021                        5              28                  0           27
#
# Disaster Subgroup  Hydrological  Meteorological
# Year
# 1900                          1               1
# 1901                          0               0
# 1902                          0               1
# 1903                          2               2
# 1904                          0               1
# ...                         ...             ...
# 2017                        152             140
# 2018                        141             124
# 2019                        221             112
# 2020                        220             133
# 2021                        170              85
#
# [122 rows x 6 columns]

# %%
 import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

disaster_subs = {
    'Climatological':'Climatological',
    'Biological':'Biological',
    'Extra-terrestrial':'Extra-terrestrial',
    'Geophysical':'Geophysical',
    'Hydrological':'Hydrological',
    'Meteorological':'Meteorological'
}

colors = ['yellowgreen','coral','cadetblue','plum','deeppink','seagreen','darkorange','gold','palevioletred','pink','purple','blue','skyblue','lightskyblue','olivedrab']
cmap = ListedColormap(colors)

def find_index(list_colors):
     random_color = random.choice(list_colors)
     index=list_colors.index(random_color)
     return index

fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(20, 20))

fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9, wspace=0.4, hspace=0.4)

for i, (name, sub_group) in enumerate(disaster_subs.items()):
    index = find_index(colors)
    
    ax[i//2, i%2].ticklabel_format(axis='both', style='plain')
    
    ax[i//2, i%2].scatter(
        emdata_org.Year[emdata_org['Disaster Subgroup'] == sub_group], 
        emdata_org['Total Deaths'][emdata_org['Disaster Subgroup'] == sub_group],
        c=colors[index]
    )
   

    font = {'family': 'serif',
            'color': 'black',
            'weight': 'bold',
            'size': 14}
    font2 = {
    'family': 'serif',
    'color': 'black',
        }
   
    fig.suptitle('Number of deaths per Disaster Subgroup from 1900-2021', fontdict=font2, fontweight='bold',size=26)

    ax[i//2, i%2].set_xlabel('Years', fontdict=font, labelpad=12)
    ax[i//2, i%2].set_ylabel('Number of deaths', fontdict=font, labelpad=12)
    ax[i//2, i%2].legend([name])

plt.show()

# %% [markdown]
# ## 1.0 Data Cleaning

# %% [markdown]
# ### 1.1 Cleaning Null values

# %%
emdata_org.head().T
# Out:
#                                          0               1  \
# Year                                  1900            1900
# Seq                                   9002            9001
# Glide                                  NaN             NaN
# Disaster Group                     Natural         Natural
# Disaster Subgroup           Climatological  Climatological
# Disaster Type                      Drought         Drought
# Disaster Subtype                   Drought         Drought
# Disaster Subsubtype                    NaN             NaN
# Event Name                             NaN             NaN
# Country                         Cabo Verde           India
# ISO                                    CPV             IND
# Region                      Western Africa   Southern Asia
# Continent                           Africa            Asia
# Location                       Countrywide          Bengal
# Origin                                 NaN             NaN
# Associated Dis                      Famine             NaN
# Associated Dis2                        NaN             NaN
# OFDA Response                          NaN             NaN
# Appeal                                  No              No
# Declaration                             No              No
# Aid Contribution                       NaN             NaN
# Dis Mag Value                          NaN             NaN
# Dis Mag Scale                          Km2             Km2
# Latitude                               NaN             NaN
# Longitude                              NaN             NaN
# Local Time                             NaN             NaN
# River Basin                            NaN             NaN
# Start Year                            1900            1900
# Start Month                            NaN             NaN
# Start Day                              NaN             NaN
# End Year                              1900            1900
# End Month                              NaN             NaN
# End Day                                NaN             NaN
# Total Deaths                       11000.0       1250000.0
# No Injured                             NaN             NaN
# No Affected                            NaN             NaN
# No Homeless                            NaN             NaN
# Total Affected                         NaN             NaN
# Insured Damages ('000 US$)             NaN             NaN
# Total Damages ('000 US$)               NaN             NaN
# CPI                               3.221647        3.221647
# Adm Level                              NaN             NaN
# Admin1 Code                            NaN             NaN
# Admin2 Code                            NaN             NaN
# Geo Locations                          NaN             NaN
#
#                                                     2                  3  \
# Year                                             1902               1902
# Seq                                                12                  3
# Glide                                             NaN                NaN
# Disaster Group                                Natural            Natural
# Disaster Subgroup                         Geophysical        Geophysical
# Disaster Type                              Earthquake  Volcanic activity
# Disaster Subtype                      Ground movement           Ash fall
# Disaster Subsubtype                               NaN                NaN
# Event Name                                        NaN        Santa Maria
# Country                                     Guatemala          Guatemala
# ISO                                               GTM                GTM
# Region                                Central America    Central America
# Continent                                    Americas           Americas
# Location                    Quezaltenango, San Marcos                NaN
# Origin                                            NaN                NaN
# Associated Dis                     Tsunami/Tidal wave                NaN
# Associated Dis2                                   NaN                NaN
# OFDA Response                                     NaN                NaN
# Appeal                                            NaN                NaN
# Declaration                                       NaN                NaN
# Aid Contribution                                  NaN                NaN
# Dis Mag Value                                     8.0                NaN
# Dis Mag Scale                                 Richter                NaN
# Latitude                                           14                NaN
# Longitude                                         -91                NaN
# Local Time                                      20:20                NaN
# River Basin                                       NaN                NaN
# Start Year                                       1902               1902
# Start Month                                       4.0                4.0
# Start Day                                        18.0                8.0
# End Year                                         1902               1902
# End Month                                         4.0                4.0
# End Day                                          18.0                8.0
# Total Deaths                                   2000.0             1000.0
# No Injured                                        NaN                NaN
# No Affected                                       NaN                NaN
# No Homeless                                       NaN                NaN
# Total Affected                                    NaN                NaN
# Insured Damages ('000 US$)                        NaN                NaN
# Total Damages ('000 US$)                      25000.0                NaN
# CPI                                          3.350513           3.350513
# Adm Level                                         NaN                NaN
# Admin1 Code                                       NaN                NaN
# Admin2 Code                                       NaN                NaN
# Geo Locations                                     NaN                NaN
#
#                                             4
# Year                                     1902
# Seq                                        10
# Glide                                     NaN
# Disaster Group                        Natural
# Disaster Subgroup                 Geophysical
# Disaster Type               Volcanic activity
# Disaster Subtype                     Ash fall
# Disaster Subsubtype                       NaN
# Event Name                        Santa Maria
# Country                             Guatemala
# ISO                                       GTM
# Region                        Central America
# Continent                            Americas
# Location                                  NaN
# Origin                                    NaN
# Associated Dis                            NaN
# Associated Dis2                           NaN
# OFDA Response                             NaN
# Appeal                                    NaN
# Declaration                               NaN
# Aid Contribution                          NaN
# Dis Mag Value                             NaN
# Dis Mag Scale                             NaN
# Latitude                                  NaN
# Longitude                                 NaN
# Local Time                                NaN
# River Basin                               NaN
# Start Year                               1902
# Start Month                              10.0
# Start Day                                24.0
# End Year                                 1902
# End Month                                10.0
# End Day                                  24.0
# Total Deaths                           6000.0
# No Injured                                NaN
# No Affected                               NaN
# No Homeless                               NaN
# Total Affected                            NaN
# Insured Damages ('000 US$)                NaN
# Total Damages ('000 US$)                  NaN
# CPI                                  3.350513
# Adm Level                                 NaN
# Admin1 Code                               NaN
# Admin2 Code                               NaN
# Geo Locations                             NaN

# %%
emdata_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16126 entries, 0 to 16125
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        16126 non-null  int64
#  1   Seq                         16126 non-null  int64
#  2   Glide                       1581 non-null   object
#  3   Disaster Group              16126 non-null  object
#  4   Disaster Subgroup           16126 non-null  object
#  5   Disaster Type               16126 non-null  object
#  6   Disaster Subtype            13016 non-null  object
#  7   Disaster Subsubtype         1077 non-null   object
#  8   Event Name                  3861 non-null   object
#  9   Country                     16126 non-null  object
#  10  ISO                         16126 non-null  object
#  11  Region                      16126 non-null  object
#  12  Continent                   16126 non-null  object
#  13  Location                    14334 non-null  object
#  14  Origin                      3794 non-null   object
#  15  Associated Dis              3348 non-null   object
#  16  Associated Dis2             707 non-null    object
#  17  OFDA Response               1694 non-null   object
#  18  Appeal                      2569 non-null   object
#  19  Declaration                 3256 non-null   object
#  20  Aid Contribution            677 non-null    float64
#  21  Dis Mag Value               4946 non-null   float64
#  22  Dis Mag Scale               14936 non-null  object
#  23  Latitude                    2729 non-null   object
#  24  Longitude                   2732 non-null   object
#  25  Local Time                  1103 non-null   object
#  26  River Basin                 1287 non-null   object
#  27  Start Year                  16126 non-null  int64
#  28  Start Month                 15739 non-null  float64
#  29  Start Day                   12498 non-null  float64
#  30  End Year                    16126 non-null  int64
#  31  End Month                   15418 non-null  float64
#  32  End Day                     12570 non-null  float64
#  33  Total Deaths                11413 non-null  float64
#  34  No Injured                  3895 non-null   float64
#  35  No Affected                 9220 non-null   float64
#  36  No Homeless                 2430 non-null   float64
#  37  Total Affected              11617 non-null  float64
#  38  Insured Damages ('000 US$)  1096 non-null   float64
#  39  Total Damages ('000 US$)    5245 non-null   float64
#  40  CPI                         15811 non-null  float64
#  41  Adm Level                   7859 non-null   object
#  42  Admin1 Code                 4581 non-null   object
#  43  Admin2 Code                 3969 non-null   object
#  44  Geo Locations               7859 non-null   object
# dtypes: float64(14), int64(4), object(27)
# memory usage: 5.5+ MB

# %%
#Sum of each missing value. 
emdata_org.isna().sum()
# Out:
# Year                              0
# Seq                               0
# Glide                         14545
# Disaster Group                    0
# Disaster Subgroup                 0
# Disaster Type                     0
# Disaster Subtype               3110
# Disaster Subsubtype           15049
# Event Name                    12265
# Country                           0
# ISO                               0
# Region                            0
# Continent                         0
# Location                       1792
# Origin                        12332
# Associated Dis                12778
# Associated Dis2               15419
# OFDA Response                 14432
# Appeal                        13557
# Declaration                   12870
# Aid Contribution              15449
# Dis Mag Value                 11180
# Dis Mag Scale                  1190
# Latitude                      13397
# Longitude                     13394
# Local Time                    15023
# River Basin                   14839
# Start Year                        0
# Start Month                     387
# Start Day                      3628
# End Year                          0
# End Month                       708
# End Day                        3556
# Total Deaths                   4713
# No Injured                    12231
# No Affected                    6906
# No Homeless                   13696
# Total Affected                 4509
# Insured Damages ('000 US$)    15030
# Total Damages ('000 US$)      10881
# CPI                             315
# Adm Level                      8267
# Admin1 Code                   11545
# Admin2 Code                   12157
# Geo Locations                  8267
# dtype: int64

# %%
# rename the dataframe.
df = emdata_org

# %%
# Check if label is null and numeric, the fill missing values.

for label, content in df.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            df[label]=content.fillna(content.median())

# %% [markdown]
# # Which disaster sub-group has a greater death impact.
#
# Climatological had the greatest death impact, followed by Biological.
#
# Extra-terrestrial had the least death impact.

# %%
'''
1. Create a dataframe with total deaths / subgroup
'''

df_total = pd.DataFrame({'Disaster Subgroup': df['Disaster Subgroup'], 
                        'Total Deaths': df['Total Deaths']
                       })
result = df_total.groupby('Disaster Subgroup')['Total Deaths'].sum()
deaths_grouped = pd.DataFrame(df.groupby('Disaster Subgroup')['Total Deaths'].sum())
deaths_grouped.plot(kind='bar',color='cadetblue',figsize=(10,5))

font = {'family': 'serif',
        'color': 'black',
        'weight': 'bold',
        'size': 14}

   
plt.title('Number of deaths per Disaster Subgroup from 1900-2021', fontdict=font2, fontweight='bold',size=16,pad=25)
plt.xlabel('Disaster Sub Group',fontdict=font, labelpad=12)
plt.ylabel('Number of deaths', fontdict=font, labelpad=12)

plt.show()

# %%
df.head(20).T
# Out:
#                                         0               1   \
# Year                                  1900            1900
# Seq                                   9002            9001
# Glide                                  NaN             NaN
# Disaster Group                     Natural         Natural
# Disaster Subgroup           Climatological  Climatological
# Disaster Type                      Drought         Drought
# Disaster Subtype                   Drought         Drought
# Disaster Subsubtype                    NaN             NaN
# Event Name                             NaN             NaN
# Country                         Cabo Verde           India
# ISO                                    CPV             IND
# Region                      Western Africa   Southern Asia
# Continent                           Africa            Asia
# Location                       Countrywide          Bengal
# Origin                                 NaN             NaN
# Associated Dis                      Famine             NaN
# Associated Dis2                        NaN             NaN
# OFDA Response                          NaN             NaN
# Appeal                                  No              No
# Declaration                             No              No
# Aid Contribution                     721.0           721.0
# Dis Mag Value                        151.5           151.5
# Dis Mag Scale                          Km2             Km2
# Latitude                               NaN             NaN
# Longitude                              NaN             NaN
# Local Time                             NaN             NaN
# River Basin                            NaN             NaN
# Start Year                            1900            1900
# Start Month                            7.0             7.0
# Start Day                             15.0            15.0
# End Year                              1900            1900
# End Month                              7.0             7.0
# End Day                               16.0            16.0
# Total Deaths                       11000.0       1250000.0
# No Injured                            50.0            50.0
# No Affected                        10000.0         10000.0
# No Homeless                         3000.0          3000.0
# Total Affected                      5965.0          5965.0
# Insured Damages ('000 US$)        172500.0        172500.0
# Total Damages ('000 US$)           60000.0         60000.0
# CPI                               3.221647        3.221647
# Adm Level                              NaN             NaN
# Admin1 Code                            NaN             NaN
# Admin2 Code                            NaN             NaN
# Geo Locations                          NaN             NaN
#
#                                                    2                  3   \
# Year                                             1902               1902
# Seq                                                12                  3
# Glide                                             NaN                NaN
# Disaster Group                                Natural            Natural
# Disaster Subgroup                         Geophysical        Geophysical
# Disaster Type                              Earthquake  Volcanic activity
# Disaster Subtype                      Ground movement           Ash fall
# Disaster Subsubtype                               NaN                NaN
# Event Name                                        NaN        Santa Maria
# Country                                     Guatemala          Guatemala
# ISO                                               GTM                GTM
# Region                                Central America    Central America
# Continent                                    Americas           Americas
# Location                    Quezaltenango, San Marcos                NaN
# Origin                                            NaN                NaN
# Associated Dis                     Tsunami/Tidal wave                NaN
# Associated Dis2                                   NaN                NaN
# OFDA Response                                     NaN                NaN
# Appeal                                            NaN                NaN
# Declaration                                       NaN                NaN
# Aid Contribution                                721.0              721.0
# Dis Mag Value                                     8.0              151.5
# Dis Mag Scale                                 Richter                NaN
# Latitude                                           14                NaN
# Longitude                                         -91                NaN
# Local Time                                      20:20                NaN
# River Basin                                       NaN                NaN
# Start Year                                       1902               1902
# Start Month                                       4.0                4.0
# Start Day                                        18.0                8.0
# End Year                                         1902               1902
# End Month                                         4.0                4.0
# End Day                                          18.0                8.0
# Total Deaths                                   2000.0             1000.0
# No Injured                                       50.0               50.0
# No Affected                                   10000.0            10000.0
# No Homeless                                    3000.0             3000.0
# Total Affected                                 5965.0             5965.0
# Insured Damages ('000 US$)                   172500.0           172500.0
# Total Damages ('000 US$)                      25000.0            60000.0
# CPI                                          3.350513           3.350513
# Adm Level                                         NaN                NaN
# Admin1 Code                                       NaN                NaN
# Admin2 Code                                       NaN                NaN
# Geo Locations                                     NaN                NaN
#
#                                            4                    5   \
# Year                                     1902                 1903
# Seq                                        10                    6
# Glide                                     NaN                  NaN
# Disaster Group                        Natural              Natural
# Disaster Subgroup                 Geophysical          Geophysical
# Disaster Type               Volcanic activity  Mass movement (dry)
# Disaster Subtype                     Ash fall             Rockfall
# Disaster Subsubtype                       NaN                  NaN
# Event Name                        Santa Maria                  NaN
# Country                             Guatemala               Canada
# ISO                                       GTM                  CAN
# Region                        Central America     Northern America
# Continent                            Americas             Americas
# Location                                  NaN       Frank, Alberta
# Origin                                    NaN                  NaN
# Associated Dis                            NaN                  NaN
# Associated Dis2                           NaN                  NaN
# OFDA Response                             NaN                  NaN
# Appeal                                    NaN                  NaN
# Declaration                               NaN                  NaN
# Aid Contribution                        721.0                721.0
# Dis Mag Value                           151.5                151.5
# Dis Mag Scale                             NaN                  NaN
# Latitude                                  NaN                  NaN
# Longitude                                 NaN                  NaN
# Local Time                                NaN                  NaN
# River Basin                               NaN                  NaN
# Start Year                               1902                 1903
# Start Month                              10.0                  4.0
# Start Day                                24.0                 29.0
# End Year                                 1902                 1903
# End Month                                10.0                  4.0
# End Day                                  24.0                 29.0
# Total Deaths                           6000.0                 76.0
# No Injured                               50.0                 23.0
# No Affected                           10000.0              10000.0
# No Homeless                            3000.0               3000.0
# Total Affected                         5965.0                 23.0
# Insured Damages ('000 US$)           172500.0             172500.0
# Total Damages ('000 US$)              60000.0              60000.0
# CPI                                  3.350513             3.479379
# Adm Level                                 NaN                  NaN
# Admin1 Code                               NaN                  NaN
# Admin2 Code                               NaN                  NaN
# Geo Locations                             NaN                  NaN
#
#                                            6                 7   \
# Year                                     1903              1904
# Seq                                        12                 3
# Glide                                     NaN               NaN
# Disaster Group                        Natural           Natural
# Disaster Subgroup                 Geophysical    Meteorological
# Disaster Type               Volcanic activity             Storm
# Disaster Subtype                     Ash fall  Tropical cyclone
# Disaster Subsubtype                       NaN               NaN
# Event Name                     Mount Karthala               NaN
# Country                         Comoros (the)        Bangladesh
# ISO                                       COM               BGD
# Region                         Eastern Africa     Southern Asia
# Continent                              Africa              Asia
# Location                                  NaN        Chittagong
# Origin                                    NaN               NaN
# Associated Dis                            NaN               NaN
# Associated Dis2                           NaN               NaN
# OFDA Response                             NaN               NaN
# Appeal                                     No               NaN
# Declaration                                No               NaN
# Aid Contribution                        721.0             721.0
# Dis Mag Value                           151.5             151.5
# Dis Mag Scale                             NaN               Kph
# Latitude                                  NaN               NaN
# Longitude                                 NaN               NaN
# Local Time                                NaN               NaN
# River Basin                               NaN               NaN
# Start Year                               1903              1904
# Start Month                               7.0              11.0
# Start Day                                15.0              15.0
# End Year                                 1903              1904
# End Month                                 7.0              11.0
# End Day                                  16.0              16.0
# Total Deaths                             17.0              20.0
# No Injured                               50.0              50.0
# No Affected                           10000.0           10000.0
# No Homeless                            3000.0            3000.0
# Total Affected                         5965.0            5965.0
# Insured Damages ('000 US$)           172500.0          172500.0
# Total Damages ('000 US$)              60000.0           60000.0
# CPI                                  3.479379          3.479379
# Adm Level                                 NaN               NaN
# Admin1 Code                               NaN               NaN
# Admin2 Code                               NaN               NaN
# Geo Locations                             NaN               NaN
#
#                                                            8   \
# Year                                                     1905
# Seq                                                         5
# Glide                                                     NaN
# Disaster Group                                        Natural
# Disaster Subgroup                                 Geophysical
# Disaster Type                             Mass movement (dry)
# Disaster Subtype                                     Rockfall
# Disaster Subsubtype                                       NaN
# Event Name                                                NaN
# Country                                                Canada
# ISO                                                       CAN
# Region                                       Northern America
# Continent                                            Americas
# Location                    Spence's Bridge, British Columbia
# Origin                                                    NaN
# Associated Dis                                            NaN
# Associated Dis2                                           NaN
# OFDA Response                                             NaN
# Appeal                                                    NaN
# Declaration                                               NaN
# Aid Contribution                                        721.0
# Dis Mag Value                                           151.5
# Dis Mag Scale                                             NaN
# Latitude                                                  NaN
# Longitude                                                 NaN
# Local Time                                                NaN
# River Basin                                               NaN
# Start Year                                               1905
# Start Month                                               8.0
# Start Day                                                13.0
# End Year                                                 1905
# End Month                                                 8.0
# End Day                                                  13.0
# Total Deaths                                             18.0
# No Injured                                               18.0
# No Affected                                           10000.0
# No Homeless                                            3000.0
# Total Affected                                           18.0
# Insured Damages ('000 US$)                           172500.0
# Total Damages ('000 US$)                              60000.0
# CPI                                                  3.479379
# Adm Level                                                 NaN
# Admin1 Code                                               NaN
# Admin2 Code                                               NaN
# Geo Locations                                             NaN
#
#                                          9                   10  \
# Year                                   1905                1906
# Seq                                       3                  14
# Glide                                   NaN                 NaN
# Disaster Group                      Natural             Natural
# Disaster Subgroup               Geophysical         Geophysical
# Disaster Type                    Earthquake          Earthquake
# Disaster Subtype            Ground movement     Ground movement
# Disaster Subsubtype                     NaN                 NaN
# Event Name                              NaN                 NaN
# Country                               India               Chile
# ISO                                     IND                 CHL
# Region                        Southern Asia       South America
# Continent                              Asia            Americas
# Location                             Kangra          Valparaiso
# Origin                                  NaN                 NaN
# Associated Dis                          NaN  Tsunami/Tidal wave
# Associated Dis2                         NaN                 NaN
# OFDA Response                           NaN                 NaN
# Appeal                                  NaN                 NaN
# Declaration                             NaN                 NaN
# Aid Contribution                      721.0               721.0
# Dis Mag Value                           8.0                 8.0
# Dis Mag Scale                       Richter             Richter
# Latitude                              32.04               33.05
# Longitude                             76.16                71.4
# Local Time                            06:20               19:57
# River Basin                             NaN                 NaN
# Start Year                             1905                1906
# Start Month                             4.0                 8.0
# Start Day                               4.0                16.0
# End Year                               1905                1906
# End Month                               4.0                 8.0
# End Day                                 4.0                16.0
# Total Deaths                        20000.0             20000.0
# No Injured                             50.0                50.0
# No Affected                         10000.0             10000.0
# No Homeless                          3000.0              3000.0
# Total Affected                       5965.0              5965.0
# Insured Damages ('000 US$)         172500.0            172500.0
# Total Damages ('000 US$)            25000.0            100000.0
# CPI                                3.479379            3.479379
# Adm Level                               NaN                 NaN
# Admin1 Code                             NaN                 NaN
# Admin2 Code                             NaN                 NaN
# Geo Locations                           NaN                 NaN
#
#                                             11              12  \
# Year                                      1906            1906
# Seq                                          2              23
# Glide                                      NaN             NaN
# Disaster Group                         Natural         Natural
# Disaster Subgroup                  Geophysical    Hydrological
# Disaster Type                       Earthquake           Flood
# Disaster Subtype               Ground movement             NaN
# Disaster Subsubtype                        NaN             NaN
# Event Name                                 NaN             NaN
# Country                               Colombia         Belgium
# ISO                                        COL             BEL
# Region                           South America  Western Europe
# Continent                             Americas          Europe
# Location                                Tumako  Louvain region
# Origin                                     NaN             NaN
# Associated Dis              Tsunami/Tidal wave             NaN
# Associated Dis2                            NaN             NaN
# OFDA Response                              NaN             NaN
# Appeal                                      No             NaN
# Declaration                                 No             NaN
# Aid Contribution                         721.0           721.0
# Dis Mag Value                              9.0           151.5
# Dis Mag Scale                          Richter             Km2
# Latitude                                1.51 N             NaN
# Longitude                             78.46 W              NaN
# Local Time                                 NaN             NaN
# River Basin                                NaN             NaN
# Start Year                                1906            1906
# Start Month                                1.0             5.0
# Start Day                                 31.0            14.0
# End Year                                  1906            1906
# End Month                                  1.0             5.0
# End Day                                   31.0            14.0
# Total Deaths                             400.0             6.0
# No Injured                                50.0            50.0
# No Affected                            10000.0         10000.0
# No Homeless                             3000.0          3000.0
# Total Affected                          5965.0          5965.0
# Insured Damages ('000 US$)            172500.0        172500.0
# Total Damages ('000 US$)               60000.0         60000.0
# CPI                                   3.479379        3.479379
# Adm Level                                  NaN             NaN
# Admin1 Code                                NaN             NaN
# Admin2 Code                                NaN             NaN
# Geo Locations                              NaN             NaN
#
#                                         13                14               15  \
# Year                                  1906              1906             1907
# Seq                                     24                15                6
# Glide                                  NaN               NaN              NaN
# Disaster Group                     Natural           Natural          Natural
# Disaster Subgroup             Hydrological    Meteorological      Geophysical
# Disaster Type                        Flood             Storm       Earthquake
# Disaster Subtype                       NaN  Tropical cyclone  Ground movement
# Disaster Subsubtype                    NaN               NaN              NaN
# Event Name                             NaN               NaN              NaN
# Country                            Belgium         Hong Kong            China
# ISO                                    BEL               HKG              CHN
# Region                      Western Europe      Eastern Asia     Eastern Asia
# Continent                           Europe              Asia             Asia
# Location                               NaN               NaN        Tien Shan
# Origin                                 NaN               NaN              NaN
# Associated Dis                         NaN               NaN              NaN
# Associated Dis2                        NaN               NaN              NaN
# OFDA Response                          NaN               NaN              NaN
# Appeal                                 NaN                No              NaN
# Declaration                            NaN                No              NaN
# Aid Contribution                     721.0             721.0            721.0
# Dis Mag Value                        151.5             151.5              7.0
# Dis Mag Scale                          Km2               Kph          Richter
# Latitude                               NaN               NaN             38.5
# Longitude                              NaN               NaN             69.9
# Local Time                             NaN               NaN            09:23
# River Basin                            NaN               NaN              NaN
# Start Year                            1906              1906             1907
# Start Month                            4.0               9.0             10.0
# Start Day                             15.0               8.0             21.0
# End Year                              1906              1906             1907
# End Month                              4.0               9.0             10.0
# End Day                               16.0               8.0             21.0
# Total Deaths                          20.0           10000.0          12000.0
# No Injured                            50.0              50.0             50.0
# No Affected                        10000.0           10000.0          10000.0
# No Homeless                         3000.0            3000.0           3000.0
# Total Affected                      5965.0            5965.0           5965.0
# Insured Damages ('000 US$)        172500.0          172500.0         172500.0
# Total Damages ('000 US$)           60000.0           20000.0          60000.0
# CPI                               3.479379          3.479379         3.608245
# Adm Level                              NaN               NaN              NaN
# Admin1 Code                            NaN               NaN              NaN
# Admin2 Code                            NaN               NaN              NaN
# Geo Locations                          NaN               NaN              NaN
#
#                                            16  \
# Year                                     1907
# Seq                                         1
# Glide                                     NaN
# Disaster Group                        Natural
# Disaster Subgroup                  Biological
# Disaster Type                        Epidemic
# Disaster Subtype            Bacterial disease
# Disaster Subsubtype                       NaN
# Event Name                            Bubonic
# Country                                 India
# ISO                                       IND
# Region                          Southern Asia
# Continent                                Asia
# Location                                  NaN
# Origin                                    NaN
# Associated Dis                            NaN
# Associated Dis2                           NaN
# OFDA Response                             NaN
# Appeal                                    NaN
# Declaration                               NaN
# Aid Contribution                        721.0
# Dis Mag Value                           151.5
# Dis Mag Scale                      Vaccinated
# Latitude                                  NaN
# Longitude                                 NaN
# Local Time                                NaN
# River Basin                               NaN
# Start Year                               1907
# Start Month                               7.0
# Start Day                                15.0
# End Year                                 1907
# End Month                                 7.0
# End Day                                  16.0
# Total Deaths                        1300000.0
# No Injured                               50.0
# No Affected                           10000.0
# No Homeless                            3000.0
# Total Affected                         5965.0
# Insured Damages ('000 US$)           172500.0
# Total Damages ('000 US$)              60000.0
# CPI                                  3.608245
# Adm Level                                 NaN
# Admin1 Code                               NaN
# Admin2 Code                               NaN
# Geo Locations                             NaN
#
#                                                           17  \
# Year                                                    1908
# Seq                                                       11
# Glide                                                    NaN
# Disaster Group                                       Natural
# Disaster Subgroup                                Geophysical
# Disaster Type                            Mass movement (dry)
# Disaster Subtype                                   Landslide
# Disaster Subsubtype                                      NaN
# Event Name                                               NaN
# Country                                               Canada
# ISO                                                      CAN
# Region                                      Northern America
# Continent                                           Americas
# Location                    Notre Dame de La Salette, Quebec
# Origin                                                   NaN
# Associated Dis                                           NaN
# Associated Dis2                                          NaN
# OFDA Response                                            NaN
# Appeal                                                   NaN
# Declaration                                              NaN
# Aid Contribution                                       721.0
# Dis Mag Value                                          151.5
# Dis Mag Scale                                            NaN
# Latitude                                                 NaN
# Longitude                                                NaN
# Local Time                                               NaN
# River Basin                                              NaN
# Start Year                                              1908
# Start Month                                              4.0
# Start Day                                               26.0
# End Year                                                1908
# End Month                                                4.0
# End Day                                                 26.0
# Total Deaths                                            33.0
# No Injured                                              50.0
# No Affected                                          10000.0
# No Homeless                                           3000.0
# Total Affected                                        5965.0
# Insured Damages ('000 US$)                          172500.0
# Total Damages ('000 US$)                             60000.0
# CPI                                                 3.479379
# Adm Level                                                NaN
# Admin1 Code                                              NaN
# Admin2 Code                                              NaN
# Geo Locations                                            NaN
#
#                                           18                19
# Year                                    1909              1909
# Seq                                       10                13
# Glide                                    NaN               NaN
# Disaster Group                       Natural           Natural
# Disaster Subgroup             Meteorological    Meteorological
# Disaster Type                          Storm             Storm
# Disaster Subtype            Tropical cyclone  Tropical cyclone
# Disaster Subsubtype                      NaN               NaN
# Event Name                               NaN               NaN
# Country                           Bangladesh        Bangladesh
# ISO                                      BGD               BGD
# Region                         Southern Asia     Southern Asia
# Continent                               Asia              Asia
# Location                           Bakerganj   West Sundarbans
# Origin                                   NaN               NaN
# Associated Dis                           NaN               NaN
# Associated Dis2                          NaN               NaN
# OFDA Response                            NaN               NaN
# Appeal                                   NaN               NaN
# Declaration                              NaN               NaN
# Aid Contribution                       721.0             721.0
# Dis Mag Value                          151.5             151.5
# Dis Mag Scale                            Kph               Kph
# Latitude                                 NaN               NaN
# Longitude                                NaN               NaN
# Local Time                               NaN               NaN
# River Basin                              NaN               NaN
# Start Year                              1909              1909
# Start Month                             10.0              12.0
# Start Day                               15.0              15.0
# End Year                                1909              1909
# End Month                               10.0              12.0
# End Day                                 15.0              16.0
# Total Deaths                           172.0              20.0
# No Injured                              50.0              50.0
# No Affected                          10000.0           10000.0
# No Homeless                           3000.0            3000.0
# Total Affected                        5965.0            5965.0
# Insured Damages ('000 US$)          172500.0          172500.0
# Total Damages ('000 US$)             60000.0           60000.0
# CPI                                 3.479379          3.479379
# Adm Level                                NaN               NaN
# Admin1 Code                              NaN               NaN
# Admin2 Code                              NaN               NaN
# Geo Locations                            NaN               NaN

# %% [markdown]
# # Continent and location

# %%
'''from geopy.geocoders import Nominatim
from geopy.exc import GeocoderUnavailable
import time

geolocator = Nominatim(user_agent="humanitarian-aid")

locations = df['Location']

coordinates = []

print('Execution started')
for location in locations:
    try:
        location = geolocator.geocode(location)
        if location is not None:
            coordinates.append((location.latitude, location.longitude))
        else:
            print(f"Skipping location: {location}")
    except GeocoderUnavailable:
        print("Geocoding service unavailable. Retrying in 1 second...")
        time.sleep(1)
        
print(coordinates)
print('Execution Ended')
# Out:
#   Cell In[14], line 1
#     '''from geopy.geocoders import Nominatim
#     ^
# SyntaxError: incomplete input

# %%
'''
# Convert the geo longitude and latitude list into a csv.
import csv

my_list = coordinates

# Specify the file path and name for the CSV file
csv_file = 'coordinates.csv'

# Open the CSV file in write mode
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the entire list as a single row in the CSV file
    writer.writerow(my_list)
    '''

# %%
'''
import folium
# create map centered on the United States
display_map = folium.Map(location=[0, 0], zoom_start=4)

# add bubbles to the map
for i, location in enumerate(locations):
    folium.CircleMarker(location=coordinates[i], radius=10, popup=location).add_to(display_map)

# display the map
display_map
'''

# %% [markdown]
# # Which disaster had a larger impact on continents?

# %%
pd.crosstab(df['Disaster Type'],df['Continent']).plot(kind='bar',figsize=(10,5),width=0.6, color =['yellowgreen','coral','cadetblue','plum','deeppink']);
plt.title('Count of Disaster Types Occurances Per Continent', fontdict=font2, fontweight='bold',size=16,pad=25)
plt.xlabel('Disaster Type',fontdict=font, labelpad=12)
plt.ylabel('Count', fontdict=font, labelpad=12)
plt.show()
